# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load_csv(filename, skip_rows):
    df = pd.read_csv(filename, skiprows=skip_rows, header=0)
    df.drop(df.columns[0], axis=1, inplace=True)
    return df

# %%
df = load_csv("/Users/austincheang/Desktop/Msc/ABM/ABM_Netlogo/experiment_data/E1_E3_2.csv", 30)

# %%
retailer_0_price = df.filter(regex='^\[ price \] of retailer 0')

# %%
retailer_1_price = df.filter(regex='^\[ price \] of retailer 1')

# %%
retailer_0_price
# Out:
#       [ price ] of retailer 0  [ price ] of retailer 0.1  \
# 0                   34.500000                  34.500000
# 1                   35.095015                  34.555466
# 2                   35.095015                  34.555466
# 3                   35.095015                  34.555466
# 4                   35.095015                  34.555466
# ...                       ...                        ...
# 1995                42.835398                  45.989346
# 1996                42.835398                  45.989346
# 1997                42.835398                  45.989346
# 1998                42.835398                  45.989346
# 1999                42.835398                  45.989346
#
#       [ price ] of retailer 0.2  [ price ] of retailer 0.3
# 0                     34.500000                  34.500000
# 1                     35.253716                  35.275147
# 2                     35.253716                  35.275147
# 3                     35.253716                  35.275147
# 4                     35.253716                  35.275147
# ...                         ...                        ...
# 1995                  37.990475                  42.902550
# 1996                  37.607177                  42.902550
# 1997                  37.607177                  42.902550
# 1998                  37.607177                  42.902550
# 1999                  37.607177                  42.902550
#
# [2000 rows x 4 columns]

# %%
retailer_1_price
# Out:
#       [ price ] of retailer 1  [ price ] of retailer 1.1  \
# 0                   43.500000                  43.500000
# 1                   43.389392                  43.041974
# 2                   43.389392                  43.041974
# 3                   43.389392                  43.041974
# 4                   43.389392                  43.041974
# ...                       ...                        ...
# 1995                45.973078                  46.191372
# 1996                45.937659                  46.102616
# 1997                45.937659                  46.102616
# 1998                45.937659                  46.102616
# 1999                45.937659                  46.102616
#
#       [ price ] of retailer 1.2  [ price ] of retailer 1.3
# 0                     43.500000                  43.500000
# 1                     43.190796                  43.193808
# 2                     43.190796                  43.193808
# 3                     43.190796                  43.193808
# 4                     43.190796                  43.193808
# ...                         ...                        ...
# 1995                  42.339365                  36.542017
# 1996                  42.339365                  36.542017
# 1997                  42.339365                  36.542017
# 1998                  42.339365                  36.542017
# 1999                  42.259009                  36.732475
#
# [2000 rows x 4 columns]

# %%
def plot_price_evolve():
    plt.figure(figsize=(8, 6))
    sns.lineplot(data=retailer_0_price["[ price ] of retailer 0.1"], label='Retailer_0');
    sns.lineplot(data=retailer_1_price["[ price ] of retailer 1.1"], label='Retailer_1');
    plt.axhline(y=30, color='r', linestyle='--', label='Unit Cost')
    plt.ylabel("Price")
    plt.xlabel("Time ticks")
    plt.title("Retailer Price evolution")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
    # plt.savefig("./table_data/Retailer_price_evolution.jpg")

# %%
plot_price_evolve()
