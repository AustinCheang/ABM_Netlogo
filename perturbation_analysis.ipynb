# %%
import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt

# %%
def load_csv(filename, skip_rows):
    df = pd.read_csv(filename, skiprows=skip_rows, header=0)
    df.drop(df.columns[0], axis=1, inplace=True)
    display(df)
    return df

def plot_market_share_trend():
    fig, ax = plt.subplots(figsize=(15, 8))
    
    filename = f'./experiment_data/perturbation.csv'
    df = load_csv(filename, 28)
    df_0 = df.iloc[:, 1::3]
    df_0.iloc[0:1000, 2] = None
    display(df_0.iloc[995:1005])
    
    ax.axhline(y=40, linestyle='--', color='red', label='even market share for 2 retailers')
    ax.axhline(y=27, linestyle='--', color='purple', label='even market share for 3 retailers')
    ax.plot(df_0['[ market-share ] of retailer 0'], label='Retailer 1')
    ax.plot(df_0['[ market-share ] of retailer 1'], label='Retailer 2')
    ax.plot(df_0['[ market-share ] of retailer third-retailer-id'], label='Retailer 3')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
    ax.set_ylabel('Market Shares')
    ax.set_xlabel('Time ticks')
    plt.title('Market shares of retailers')
    plt.plot()

# %%
plot_market_share_trend()
# Out:
#       [ cumulative-profit ] of retailer 0  [ market-share ] of retailer 0  \
# 0                                0.000000                              44
# 1                              491.027096                              35
# 2                              491.027096                              44
# 3                              586.294387                              41
# 4                              681.561678                              43
# ...                                   ...                             ...
# 1995                        244284.831766                              27
# 1996                        244398.421239                              26
# 1997                        244562.494922                              27
# 1998                        244562.494922                              28
# 1999                        244701.326501                              25
#
#       [ price ] of retailer 0  [ cumulative-profit ] of retailer 1  \
# 0                   44.029346                             0.000000
# 1                   43.609613                           243.859183
# 2                   43.609613                           243.859183
# 3                   43.609613                           299.736516
# 4                   43.609613                           334.659849
# ...                       ...                                  ...
# 1995                42.621053                         82573.040304
# 1996                42.621053                         82608.013890
# 1997                42.621053                         82657.976155
# 1998                42.621053                         82657.976155
# 1999                42.408359                         82732.919553
#
#       [ market-share ] of retailer 1  [ price ] of retailer 1  \
# 0                                 36                36.773866
# 1                                 36                36.984667
# 2                                 36                36.984667
# 3                                 36                36.984667
# 4                                 36                36.984667
# ...                              ...                      ...
# 1995                              22                34.996227
# 1996                              22                34.996227
# 1997                              22                34.996227
# 1998                              22                34.996227
# 1999                              22                34.996227
#
#       [ cumulative-profit ] of retailer third-retailer-id  \
# 0                                              0.000000
# 1                                            491.027096
# 2                                            491.027096
# 3                                            586.294387
# 4                                            681.561678
# ...                                                 ...
# 1995                                       61752.081660
# 1996                                       61892.824683
# 1997                                       61980.789072
# 1998                                       61980.789072
# 1999                                       62103.939218
#
#       [ market-share ] of retailer third-retailer-id  \
# 0                                                 44
# 1                                                 35
# 2                                                 44
# 3                                                 41
# 4                                                 43
# ...                                              ...
# 1995                                              30
# 1996                                              30
# 1997                                              30
# 1998                                              30
# 1999                                              30
#
#       [ price ] of retailer third-retailer-id
# 0                                   44.029346
# 1                                   43.609613
# 2                                   43.609613
# 3                                   43.609613
# 4                                   43.609613
# ...                                       ...
# 1995                                38.796439
# 1996                                38.796439
# 1997                                38.796439
# 1998                                38.796439
# 1999                                38.796439
#
# [2000 rows x 9 columns]
#       [ market-share ] of retailer 0  [ market-share ] of retailer 1  \
# 995                               40                              39
# 996                               40                              39
# 997                               39                              39
# 998                               44                              36
# 999                               44                              36
# 1000                              44                              36
# 1001                              31                              27
# 1002                              31                              27
# 1003                              29                              27
# 1004                              31                              27
#
#       [ market-share ] of retailer third-retailer-id
# 995                                              NaN
# 996                                              NaN
# 997                                              NaN
# 998                                              NaN
# 999                                              NaN
# 1000                                             0.0
# 1001                                            22.0
# 1002                                            22.0
# 1003                                            23.0
# 1004                                            22.0
